# %% [markdown]
# # Ground Motion Displacement RMS vs Time
#
# *an example simple tutorial for getting seismic data, computing the power spectral densities, extracting the RMS and plotting*
#
# Required:
#
# - python
# - obspy (and its dependencies)
# - pandas
# - jupyter
# - notebook
# - tqdm
#
# this should be easy to set up in a conda env: ``conda create -c conda-forge -n covid python=3.7 obspy pandas jupyter notebook tqdm``
#
# Author: Thomas Lecocq @seismotom, Fred Massin @fmassin, Claudio Satriano @claudiodsf

# %% [markdown]
# ## Step 1: imports

# %%
import datetime
import os
from glob import glob

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42  # to edit text in Illustrator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as pe
import numpy as np
import pandas as pd
import tqdm
import warnings

from obspy import UTCDateTime, read
from obspy.clients.fdsn import Client
from obspy.clients.fdsn.client import FDSNNoDataException
from obspy.signal import PPSD

# %load_ext autoreload
# %autoreload 2
import seismosocialdistancing_core as seismosocialdistancing

# %% [markdown]
# ## Step 2: Define Start/End dates and Seismic Channel
#
# You'll have to make sure the seed_id you request is indeed available from the ``data_provider``

# %%
## The station information is provided in a file called `seismosocialdistancing_settings.py 

import seismosocialdistancing_settings as ssd

start = ssd.start
end = ssd.end
safety_window = ssd.safety_window

network   = ssd.network
station   = ssd.station
location  = ssd.location
channel   = ssd.channel
dataset   = ssd.dataset
time_zone = ssd.time_zone
sitedesc  = ssd.sitedesc

reference_period=ssd.reference
lockdown_period=ssd.lockdown
reopening_date=ssd.reopening
holiday_period=ssd.summer_hol

data_provider = ssd.data_provider
logo = ssd.logo
bans = ssd.bans

datelist = pd.date_range(start.datetime, min(end, UTCDateTime()).datetime, freq="D")

# This is the current date in pandas format
today = pd.to_datetime(UTCDateTime.now().date)

# %% [markdown]
# ## Step 3: Download the seismic waveform data
#
# This step is coded so that only the last day is redownloaded if the daily files are present on the disk.
#
# The request gets the target day +- 30 minutes to avoid having gaps at the end of each day (need 1 window covering midnight).

# %%
force_reprocess = False

import pathlib
pathlib.Path(os.path.join("..","data")).mkdir(parents=True, exist_ok=True)
pathlib.Path(os.path.join("..","workdir")).mkdir(parents=True, exist_ok=True)


c = Client(data_provider, timeout=10.0)

nslc = "{}.{}.{}.{}".format(network, station, location, channel)
# make sure that wildcard characters are not in nslc
nslc = nslc.replace("*", "").replace("?", "")
pbar = tqdm.tqdm(datelist)
goodday=None

for day in pbar:
    datestr = day.strftime("%Y-%m-%d")
    fn  = os.path.join("..","workdir","{}_{}_{}.mseed".format(dataset, datestr, nslc))
    fnz = os.path.join("..","data","{}_{}_{}.npz".format(dataset, datestr, nslc))
    
    if (today-day > safety_window) and (os.path.isfile(fn) or (os.path.isfile(fnz) and not force_reprocess)):
        pbar.set_description("Using cache - %s" % fn)
        goodday = day
        continue
    else:
        pbar.set_description("Fetching    - %s" % fn)
        try: 
            st = c.get_waveforms(network, station, location, channel,
                                  UTCDateTime(day)-1801, UTCDateTime(day)+86400+1801,
                                  attach_response=True)
            goodday=day
        except FDSNNoDataException:
            print("No data on FDSN server for %s" % fn)
            pbar.set_description("No data on FDSN server for %s" % fn)
            continue
        st.write(fn)

# This is to ensure that we get recent information but allow fallback to earlier dates 

for day in datelist[::-1]:  
    try:
        resp = c.get_stations(UTCDateTime(day), network=network, station=station, location=location,
                      channel=channel, level="response")
        print("Response for date: {}".format(day))
        print(resp)
        break
    except:
        print("Exception for date: {}".format(day))
        pass
# Out:
# Fetching    - ../workdir/Australia_AUMAR_2020-01-08_S1.AUMAR..BHZ.mseed:   6%|▌         | 26/471 [00:00<00:03, 127.55it/s]
# No data on FDSN server for ../workdir/Australia_AUMAR_2019-12-26_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2019-12-27_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2019-12-28_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2019-12-29_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2019-12-30_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2019-12-31_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-01-01_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-01-02_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-01-03_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-01-04_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-01-05_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-01-06_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-01-07_S1.AUMAR..BHZ.mseed
# Fetching    - ../workdir/Australia_AUMAR_2020-06-27_S1.AUMAR..BHZ.mseed:  43%|████▎     | 201/471 [00:01<00:01, 180.77it/s]
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-06-18_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-06-19_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-06-20_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-06-21_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-06-22_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-06-23_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-06-24_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-06-25_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-06-26_S1.AUMAR..BHZ.mseed
# Using cache - ../workdir/Australia_AUMAR_2020-07-01_S1.AUMAR..BHZ.mseed:  43%|████▎     | 201/471 [00:01<00:01, 180.77it/s]
# No data on FDSN server for ../workdir/Australia_AUMAR_2020-06-28_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-05_S1.AUMAR..BHZ.mseed:  91%|█████████▏| 430/471 [00:11<00:02, 17.36it/s]
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-01-22_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-01-23_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-01-24_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-01-25_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-01-26_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-01-27_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-01-28_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-01-29_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-01-30_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-01-31_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-01_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-02_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-03_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-04_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-05_S1.AUMAR..BHZ.mseed
# Fetching    - ../workdir/Australia_AUMAR_2021-02-16_S1.AUMAR..BHZ.mseed:  91%|█████████▏| 430/471 [00:12<00:02, 17.36it/s]
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-06_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-07_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-08_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-09_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-10_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-11_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-12_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-13_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-14_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-15_S1.AUMAR..BHZ.mseed
# Fetching    - ../workdir/Australia_AUMAR_2021-02-28_S1.AUMAR..BHZ.mseed:  96%|█████████▌| 452/471 [00:12<00:01, 18.98it/s]
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-16_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-17_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-18_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-19_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-20_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-21_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-22_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-23_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-24_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-25_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-26_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-27_S1.AUMAR..BHZ.mseed
# Fetching    - ../workdir/Australia_AUMAR_2021-03-11_S1.AUMAR..BHZ.mseed:  96%|█████████▌| 452/471 [00:12<00:01, 18.98it/s]
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-02-28_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-01_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-02_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-03_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-04_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-05_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-06_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-07_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-08_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-09_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-10_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-15_S1.AUMAR..BHZ.mseed: 100%|██████████| 471/471 [00:12<00:00, 36.63it/s]
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-11_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-12_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-13_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-14_S1.AUMAR..BHZ.mseed
# No data on FDSN server for ../workdir/Australia_AUMAR_2021-03-15_S1.AUMAR..BHZ.mseed
# Response for date: 2021-03-15 00:00:00
# Inventory created at 2021-03-16T03:34:07.720711Z
# 	Sending institution: SeisComP (RSES)
# 	Contains:
# 		Networks (1):
# 			S1
# 		Stations (1):
# 			S1.AUMAR (Marden Senior College)
# 		Channels (1):
# 			S1.AUMAR..BHZ

# %%
st = c.get_waveforms(network, station, location, channel,
                                  UTCDateTime(goodday)-1801, UTCDateTime(goodday)+86400+1801,
                                  attach_response=True)

# %% [markdown]
# ## Step 4: Compute PPSDs using custom parameters
#
# These parameters are set to allow the PSDs to be "nervous", not as smooth as the default PQLX ones.

# %%
pbar = tqdm.tqdm(datelist)
for day in pbar:
    datestr = day.strftime("%Y-%m-%d")
    fn_in = os.path.join("..","workdir","{}_{}_{}.mseed".format(dataset, datestr, nslc))
    pbar.set_description("Processing %s" % fn_in)
    if not os.path.isfile(fn_in):
        continue
    stall = read(fn_in, headonly=True)
    for mseedid in list(set([tr.id for tr in stall])):
        fn_out = os.path.join("..","data","{}_{}_{}.npz".format(dataset, datestr, mseedid))
        if (today-day > safety_window) and (os.path.isfile(fn_out) and not force_reprocess):
            continue
        st = read(fn_in, sourcename=mseedid)
        st.attach_response(resp)
        ppsd = PPSD(st[0].stats, metadata=resp,
                    ppsd_length=1800, overlap=0.5,
                    period_smoothing_width_octaves=0.025,
                    period_step_octaves=0.0125,
                    period_limits=(0.008, 50),
                    db_bins=(-200, 20, 0.25))
        with warnings.catch_warnings():
            warnings.simplefilter("ignore")
            ppsd.add(st)
        ppsd.save_npz(fn_out[:-4])
        del st, ppsd
    del stall
# Out:
# Processing ../workdir/Australia_AUMAR_2021-03-15_S1.AUMAR..BHZ.mseed: 100%|██████████| 471/471 [02:39<00:00,  2.95it/s]

# %% [markdown]
# ## Step 5: Reload daily PSDs from the disk and create a single PPSD object:

# %%
ppsds = {}
pbar = tqdm.tqdm(datelist)
for day in pbar:
    datestr = day.strftime("%Y-%m-%d")
    fn_pattern = os.path.join("..","data","{}_{}_*.npz".format(dataset, datestr))
    pbar.set_description("Reading %s" % fn_pattern)
    for fn in glob(fn_pattern):
        mseedid = fn.replace(".npz", "").split("_")[-1]
        if mseedid not in ppsds:
            ppsds[mseedid] = PPSD.load_npz(fn)#, allow_pickle=True)
        else:
            with warnings.catch_warnings():
                warnings.simplefilter("ignore")
                ppsds[mseedid].add_npz(fn)#, allow_pickle=True)
# Out:
# Reading ../data/Australia_AUMAR_2021-03-15_*.npz: 100%|██████████| 471/471 [00:06<00:00, 68.05it/s]

# %% [markdown]
# ## Step 6: Standard plots:

# %%
[ppsd.plot(max_percentage=10) for mseedid, ppsd in ppsds.items()]
[ppsd.plot_temporal(0.10) for mseedid, ppsd in ppsds.items()]
[ppsd.plot_spectrogram(clim=(-160,-100)) for mseedid, ppsd in ppsds.items()]
# Out:
# [None]

# %% [markdown]
# ## Step 7: Process PSDs to extract the RMS(displacement)
#
# This can be done for multiple filters at once (``freqs`` below):

# %%
# Define frequency bands of interest:
freqs = [(0.1,1.0),(1.0,20.0),(4.0,14.0),(4.0,20.0)]

displacement_RMS = {}
for mseedid, ppsd in tqdm.tqdm(ppsds.items()):
    ind_times = pd.DatetimeIndex([d.datetime for d in ppsd.current_times_used])
    data = pd.DataFrame(ppsd.psd_values, index=ind_times, columns=1./ppsd.period_bin_centers)
    data = data.sort_index(axis=1)
    displacement_RMS[mseedid] = seismosocialdistancing.df_rms(data, freqs, output="DISP")
    # displacement_RMS[mseedid].to_csv(os.path.join("..", "results", "%s.csv" % mseedid))
    displacement_RMS[mseedid].to_csv(os.path.join("..", "results", "latest.csv"))
# Out:
# 100%|██████████| 1/1 [00:18<00:00, 18.23s/it]

# %% [markdown]
# ## Weekday / Time of day Analysis

# %%
args = {'band':"4.0-14.0",       # might be None or commented ("4.0-14.0" per default) or any of the tupples in freqs
        'time_zone':time_zone,   # required for clockplots
        'sitedesc':sitedesc,     # might be None or commented
        'logo':logo,             # might be None or commented
        'bans':bans,             # might be None or commented
        'save':'../results/',    # might be None or commented or a path 
        'unit':'nm',
        'format':'png',
        'show':True,
        'basename':"../results/latest",      # to over-ride the default name
        'reference_period':reference_period,
        'lockdown_period':lockdown_period,
        'reopening_date':reopening_date,
        'holiday_period':holiday_period
       }

seismosocialdistancing.plot(displacement_RMS,
                            type='timeseries',
                            **args)
# Out:
# /Users/lmoresi/+Github/Seismic_Noise_AuSIS_MAR/notebooks/seismosocialdistancing_core.py:747: FutureWarning: tshift is deprecated and will be removed in a future version. Please use shift instead.
#   rs = rs.resample("1D" ).median().tshift(12, "H")

# %%
# seismosocialdistancing.plot(displacement_RMS,
#                             type='dailyplots',
#                             **args)

# %%
import seismosocialdistancing_core as seismosocialdistancing

# %%
seismosocialdistancing.plot(displacement_RMS,
                            type='sclockplots',
                            **args)
# Out:
# clock plot - radial scale: 23.083423921309006 nm
# /Users/lmoresi/+Github/Seismic_Noise_AuSIS_MAR/notebooks/seismosocialdistancing_core.py:618: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["%.2g %s" %(i,unit) for i in ax.get_yticks()], fontsize=7)
# /Users/lmoresi/+Github/Seismic_Noise_AuSIS_MAR/notebooks/seismosocialdistancing_core.py:618: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["%.2g %s" %(i,unit) for i in ax.get_yticks()], fontsize=7)
# /Users/lmoresi/+Github/Seismic_Noise_AuSIS_MAR/notebooks/seismosocialdistancing_core.py:618: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["%.2g %s" %(i,unit) for i in ax.get_yticks()], fontsize=7)
# /Users/lmoresi/+Github/Seismic_Noise_AuSIS_MAR/notebooks/seismosocialdistancing_core.py:618: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(["%.2g %s" %(i,unit) for i in ax.get_yticks()], fontsize=7)

# %% [markdown]
# ## Noise distribution over time of the day

# %%
# seismosocialdistancing.plot(displacement_RMS,
#                             type='clockmaps',
#                             **args)

# %%
seismosocialdistancing.plot(displacement_RMS,
                            type='gridmaps',
                            **args)

# %% [markdown]
# ## Temporary code: All your stations' colormapped plot

# %%
normalize = True
resample_freq = "1H"
clip = (0.05,0.95)

#concatenating in a single dataframe and converting to nm
dRMS2D = pd.concat(displacement_RMS, axis=0) * 1e9
for band in dRMS2D.columns:
    g = dRMS2D.loc[:,band].unstack().T
    g = g.clip(g.quantile(clip[0]),g.quantile(clip[1]),axis=1)
    g = g.resample(resample_freq).median()
    if normalize:
        g -= g.quantile(0.01)
        g /= g.quantile(0.99)
        vmin, vmax = 0, 1
    else:
        vmin = vmax = None
   
    fig, ax = plt.subplots(1,1, figsize=(12,2*len(g.columns)))
    label = '%sDisplacement (µm)' % ["","Normalized "][normalize]

    x = np.append(g.index.values, g.index.shift(1).values[-1])
    y = np.append(g.columns, "")
    plt.pcolormesh(x, y, g.T,  cmap="inferno", vmin=vmin, vmax=vmax)
    plt.colorbar(orientation='horizontal', shrink=0.3).set_label(label)
    pos, l = plt.yticks()
    plt.yticks(np.asarray(pos)+0.5, y)
    plt.margins(0)
    plt.title("%s Hz" % band)
    plt.gca().invert_yaxis()
    plt.show()
